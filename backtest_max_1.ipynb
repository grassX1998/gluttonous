# %%
# main.py

import polars as pl
import os
import time

from dataclasses import dataclass
from src.futuapi.futu_api import FutuApi
from src.calculator.mathmatics import add_mean, add_boll

# 设置 Polars 显示的最大行数和列数
# pl.Config.set_tbl_width(1000)  # 设置表格的最大宽度，单位为字符
pl.Config.set_tbl_cols(100)  # 设置显示的最大列数
pl.Config.set_tbl_rows(10)  # 设置显示的最大行数


def parse_df_time(df):
    df = df.with_columns(
        pl.col("time_key").str.strptime(pl.Datetime, format="%Y-%m-%d %H:%M:%S"),
        pl.col("close").cast(pl.Float64).alias("price"),
    )
    df = df.with_columns(
        [
            pl.col("time_key").dt.date().cast(pl.Utf8).alias("date"),
            pl.col("time_key").dt.time().cast(pl.Utf8).alias("time"),
        ]
    )
    return df


def trans(fund_df: pl.DataFrame, index_df: pl.DataFrame):
    fund_df = (
        parse_df_time(fund_df)
        .filter(pl.col("time") == "14:50:00")
        .select(["date", "price"])
    )
    # print(fund_df)

    index_df = parse_df_time(index_df)
    df_index_vol = (
        index_df.group_by("date")
        .agg([pl.col("volume").sum().alias("volume")])
        .sort("date")
    )
    df_index_check_vol = (
        index_df.filter(pl.col("time") <= "14:50:00")
        .group_by("date")
        .agg([pl.col("volume").sum().alias("check_volume")])
        .sort("date")
    )
    df_index_check_price = (
        index_df.filter(pl.col("time") == "14:50:00")
        .with_columns(pl.col("price").cast(pl.Float64).alias("check_index_price"))
        .select("date", "check_index_price")
    )

    df = (
        index_df.filter(pl.col("time") == "15:00:00")
        .with_columns(pl.col("price").cast(pl.Float64).alias("index_price"))
        .select("date", "index_price")
        .join(df_index_check_vol, on=["date"])
        .join(df_index_vol, on=["date"])
        .join(df_index_check_price, on=["date"])
        .join(fund_df, on=["date"])
    ).select(
        ["date", "check_volume", "volume", "check_index_price", "index_price", "price"]
    )
    df = df.sort("date")
    # print(index_df)
    df = df.with_columns(
        pl.col("index_price").shift(1).rolling_max(window_size=25).alias("max_25")
    )
    df = df.with_columns(
        pl.col("check_volume")
        .shift(1)
        .rolling_mean(window_size=10)
        .cast(pl.Int64)
        .alias("avg_vol_10")
    )

    # df = df.with_columns(pl.col("price").rolling_mean(5).alias(f"ma_5"))
    # df = df.with_columns(pl.col("price").rolling_mean(20).alias(f"ma_20"))
    # df = df.with_columns(pl.col("price").rolling_mean(60).alias(f"ma_60"))
    # df = df.with_columns(pl.col("price").rolling_mean(120).alias(f"ma_120"))

    # df = df.with_columns(
    #     pl.col("price").rolling_min(window_size=5, min_periods=1).alias("min_5")
    # )
    # df = df.with_columns([(pl.col("price") - pl.col("price").shift(5)).alias("del_10")])

    # print(df)

    return df


@dataclass
class FundRecord:
    date: str
    code: str
    price: float
    check_index_price: float
    index_price: float
    check_volume: int
    volume: int
    max_25: float
    avg_vol_10: int


sub_info = [
    {
        "code": "SH.512880",
        "index": "SZ.399975",
    },
    {
        "code": "SH.510300",
        "index": "SH.000300",
    },
    # {
    #     'code': 'SH.510500',
    #     'index': 'SH.000905',
    # },
    {"code": "SH.512100", "index": "SH.000852"},
]


class MarketDataMap:
    def __init__(self):
        self.raw_data = {}
        self.start_date = "2017-01-01"
        self.end_date = "2024-12-02"

    def init_data(self):
        api = FutuApi()
        try:
            for sub_dict in sub_info:
                fund_df = api.get_minute_kline(
                    sub_dict["code"], self.start_date, self.end_date
                )
                index_df = api.get_minute_kline(
                    sub_dict["index"], self.start_date, self.end_date
                )
                df = trans(fund_df, index_df)
                for row in df.iter_rows(named=True):
                    date = row["date"]
                    if date not in self.raw_data:
                        self.raw_data[date] = []
                    record = FundRecord(
                        code=sub_dict["code"],
                        date=row["date"],
                        price=row["price"],
                        check_index_price=row["check_index_price"],
                        index_price=row["index_price"],
                        check_volume=row["check_volume"],
                        volume=row["volume"],
                        max_25=row["max_25"],
                        avg_vol_10=row["avg_vol_10"],
                    )
                    self.raw_data[date].append(record)
        finally:
            api.close()

        # for date, data in self.raw_data.items():
        #     print(date, data)
        #     time.sleep(1)


market_data_map = MarketDataMap()
market_data_map.init_data()
# Out:
# 2024-12-03 12:59:51,602 | 58803 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=9, host=127.0.0.1, port=11111, user_id=13389358
# Error retrieving trading days: Invalid time period
# Trading days saved to /data/futu/A-shares/cfg/trading_days.toml
# Processing trading days: 100%|██████████| 221/221 [00:00<00:00, 3183.53it/s]
# Processing trading days: 100%|██████████| 221/221 [00:00<00:00, 3371.99it/s]
# Processing trading days: 100%|██████████| 221/221 [00:00<00:00, 3368.34it/s]
# Processing trading days: 100%|██████████| 221/221 [00:00<00:00, 3378.72it/s]
# Processing trading days: 100%|██████████| 221/221 [00:00<00:00, 3293.36it/s]
# Processing trading days: 100%|██████████| 221/221 [00:00<00:00, 3269.09it/s]
# 2024-12-03 12:59:52,139 | 58803 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=9

# %%
import math
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator


def truncate_float(number, t):
    """
    截断浮点数到指定的小数位数，不进行四舍五入。

    :param number: 要截断的浮点数
    :param decimals: 小数位数
    :return: 截断后的浮点数
    """
    factor = 10.0**t
    truncated = math.trunc(number * factor) / factor
    return truncated


def show_rate(x: list, y: list):
    ax = plt.gca()  # 获取当前轴对象
    ax.xaxis.set_major_locator(
        MaxNLocator(integer=True, prune="both", nbins=6)
    )  # 自动选择6个关键点显示
    plt.plot(x, y, linestyle="-", linewidth=1, color="b", label="y = raw")
    # plt.plot(x, py, linestyle="-", linewidth=1, color="r", label="py = main")
    plt.title(f"str_max_fund_1")
    plt.xlabel("date")
    plt.ylabel("rate")
    plt.xticks(rotation=45, fontsize=10)
    plt.tight_layout()
    plt.grid(True, linestyle="--", alpha=0.5)
    # 显示图例
    plt.legend()

    # 显示图形
    plt.show()


class SecSignal:
    def __init__(self):
        self.on_position = False
        self.price = 0.0
        self.rate = 0.0
        self.max_price = 0.0

    def check(self, record: FundRecord):
        if self.on_position:
            if (
                record.check_index_price <= record.max_25 * 0.95
                or record.check_volume < record.avg_vol_10
            ):
                self.rate = record.price * 100 / self.price - 100
                self.on_position = False
                self.max_price = 0
                return "Sale"
        else:
            if (
                record.check_index_price >= record.max_25
                and record.check_volume > record.avg_vol_10 * 1.2
            ):
                self.price = record.price
                self.on_position = True
                self.max_price = record.price
                return "Buy"
        self.max_price = max(self.max_price, record.price)
        return "None"


class FundAccount:
    def __init__(self):
        self.init = 100000
        self.cash = 100000
        self.position = {}
        self.fee = 0.001
        # self.buys = []
        # self.sales = []
        # self.has_position = 0
        # self.no_position = 0
        self.max_val = 0.0
        self.max_drawdone = 0.0
        self.rate = 0.0

        self.max_val = 0.0
        self.max_drawdone = 0.0

        self.has_position_days = 0
        self.days = 0

    def val(self, records: list):
        result = 0.0
        result += self.cash
        result += sum(
            [
                self.position[record.code] * record.price
                for record in records
                if record.code in self.position
            ]
        )
        return result

    def buy_record(self, deno: int, record: FundRecord):
        t_cash = self.cash / deno
        t_price = record.price * (1 + self.fee)
        cnt = truncate_float(t_cash / t_price, -2)
        self.position[record.code] = cnt
        self.cash -= cnt * t_price

    def buy(self, buy_list: list):
        i = 0
        for deno in range(2, len(self.position), -1):
            if len(buy_list) <= i:
                break
            self.buy_record(deno, buy_list[i][0])
            i += 1

    def sale_record(self, record: FundRecord):
        if record.code not in self.position:
            print(f"err: not find record postion for code {record.code}")
            return
        t_price = record.price * (1.0 - self.fee)
        self.cash += self.position[record.code] * t_price
        print(self.cash)
        del self.position[record.code]

    def sale(self, sale_list: list):
        for [record, rate] in sale_list:
            self.sale_record(record)

    def print_meta(self, records: list):
        val = self.val(records)
        self.days += 1
        if len(self.position) != 0:
            self.has_position_days += 1
        self.max_val = max(self.max_val, val)
        self.max_drawdone = min(self.max_drawdone, val * 100 / self.max_val - 100.0)
        print(
            f"max_val: {self.max_val}, max_drawdone: {self.max_drawdone}, rate: {val * 100 / self.init - 100.0}, has position day: {self.has_position_days}, has position rate: {self.has_position_days * 100 / self.days}"
        )


fund_account = FundAccount()
signals = {}
for sub_dict in sub_info:
    signals[sub_dict["code"]] = SecSignal()

x = []
y = []

for date, records in market_data_map.raw_data.items():
    if records[0].max_25 == None:
        continue
    # print(date, records)
    buy_list = []
    sale_list = []
    for record in records:
        sig = signals[record.code].check(record)
        if sig == "Sale":
            sale_list.append([record, signals[record.code].rate])
        elif sig == "Buy":
            buy_list.append([record])
        # sig_list.append([record.code, sig])

    fund_account.sale(sale_list)
    fund_account.buy(buy_list)
    val = fund_account.val(records)
    fund_account.print_meta(records)
    print(
        date,
        "sale: ",
        [[ele[0].code, ele[1]] for ele in sale_list],
        "buy: ",
        [[ele[0].code] for ele in buy_list],
        "val: ",
        val,
    )

    x.append(date)
    y.append(val * 100 / 100000 - 100.0)

show_rate(x, y)

# time.sleep(1)
# Out:
# max_val: 100000.0, max_drawdone: 0.0, rate: 0.0, has position day: 0, has position rate: 0.0
# 2024-02-06 sale:  [] buy:  [] val:  100000.0
# max_val: 100000.0, max_drawdone: 0.0, rate: 0.0, has position day: 0, has position rate: 0.0
# 2024-02-07 sale:  [] buy:  [] val:  100000.0
# max_val: 100000.0, max_drawdone: 0.0, rate: 0.0, has position day: 0, has position rate: 0.0
# 2024-02-08 sale:  [] buy:  [] val:  100000.0
# max_val: 100000.0, max_drawdone: 0.0, rate: 0.0, has position day: 0, has position rate: 0.0
# 2024-02-19 sale:  [] buy:  [] val:  100000.0
# max_val: 100000.0, max_drawdone: 0.0, rate: 0.0, has position day: 0, has position rate: 0.0
# 2024-02-20 sale:  [] buy:  [] val:  100000.0
# max_val: 100000.0, max_drawdone: -0.049929000000005885, rate: -0.049929000000005885, has position day: 1, has position rate: 16.666666666666668
# 2024-02-21 sale:  [] buy:  [['SH.512880']] val:  99950.071
# 100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 14.285714285714286
# 2024-02-22 sale:  [['SH.512880', 0.8988764044943736]] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 12.5
# 2024-02-23 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 11.11111111111111
# 2024-02-26 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 10.0
# 2024-02-27 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 9.090909090909092
# 2024-02-28 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 8.333333333333334
# 2024-02-29 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 7.6923076923076925
# 2024-03-01 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 7.142857142857143
# 2024-03-04 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 6.666666666666667
# 2024-03-05 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 6.25
# 2024-03-06 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 5.882352941176471
# 2024-03-07 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 5.555555555555555
# 2024-03-08 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 5.2631578947368425
# 2024-03-11 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 5.0
# 2024-03-12 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 4.761904761904762
# 2024-03-13 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 4.545454545454546
# 2024-03-14 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 4.3478260869565215
# 2024-03-15 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 4.166666666666667
# 2024-03-18 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 4.0
# 2024-03-19 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 3.8461538461538463
# 2024-03-20 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 3.7037037037037037
# 2024-03-21 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 3.5714285714285716
# 2024-03-22 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 3.4482758620689653
# 2024-03-25 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 3.3333333333333335
# 2024-03-26 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 3.225806451612903
# 2024-03-27 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 3.125
# 2024-03-28 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 3.0303030303030303
# 2024-03-29 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.9411764705882355
# 2024-04-01 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.857142857142857
# 2024-04-02 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.7777777777777777
# 2024-04-03 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.7027027027027026
# 2024-04-08 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.6315789473684212
# 2024-04-09 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.5641025641025643
# 2024-04-10 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.5
# 2024-04-11 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.4390243902439024
# 2024-04-12 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.380952380952381
# 2024-04-15 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.3255813953488373
# 2024-04-16 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.272727272727273
# 2024-04-17 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.2222222222222223
# 2024-04-18 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.1739130434782608
# 2024-04-19 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.127659574468085
# 2024-04-22 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.0833333333333335
# 2024-04-23 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.0408163265306123
# 2024-04-24 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 2.0
# 2024-04-25 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.34849320000000716, has position day: 1, has position rate: 1.9607843137254901
# 2024-04-26 sale:  [] buy:  [] val:  100348.4932
# max_val: 100348.4932, max_drawdone: -0.049929000000005885, rate: 0.2986062000000089, has position day: 2, has position rate: 3.8461538461538463
# 2024-04-29 sale:  [] buy:  [['SH.510300']] val:  100298.60620000001
# max_val: 100348.4932, max_drawdone: -0.20098657545162268, rate: 0.14680620000001454, has position day: 3, has position rate: 5.660377358490566
# 2024-04-30 sale:  [] buy:  [] val:  100146.8062
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7678061999999954, has position day: 4, has position rate: 7.407407407407407
# 2024-05-06 sale:  [] buy:  [] val:  100767.80619999999
# 100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 7.2727272727272725
# 2024-05-07 sale:  [['SH.510300', 0.9128630705394158]] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 7.142857142857143
# 2024-05-08 sale:  [] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 7.017543859649122
# 2024-05-09 sale:  [] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 6.896551724137931
# 2024-05-10 sale:  [] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 6.779661016949152
# 2024-05-13 sale:  [] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 6.666666666666667
# 2024-05-14 sale:  [] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 6.557377049180328
# 2024-05-15 sale:  [] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 6.451612903225806
# 2024-05-16 sale:  [] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.7036638000000153, has position day: 4, has position rate: 6.349206349206349
# 2024-05-17 sale:  [] buy:  [] val:  100703.66380000001
# max_val: 100767.80619999999, max_drawdone: -0.20098657545162268, rate: 0.6535478000000126, has position day: 5, has position rate: 7.8125
# 2024-05-20 sale:  [] buy:  [['SH.510300']] val:  100653.54780000001
# 100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 7.6923076923076925
# 2024-05-21 sale:  [['SH.510300', -0.4613297150610549]] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 7.575757575757576
# 2024-05-22 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 7.462686567164179
# 2024-05-23 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 7.352941176470588
# 2024-05-24 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 7.246376811594203
# 2024-05-27 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 7.142857142857143
# 2024-05-28 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 7.042253521126761
# 2024-05-29 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.944444444444445
# 2024-05-30 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.8493150684931505
# 2024-05-31 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.756756756756757
# 2024-06-03 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.666666666666667
# 2024-06-04 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.578947368421052
# 2024-06-05 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.4935064935064934
# 2024-06-06 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.410256410256411
# 2024-06-07 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.329113924050633
# 2024-06-11 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.25
# 2024-06-12 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.172839506172839
# 2024-06-13 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.097560975609756
# 2024-06-14 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 6.024096385542169
# 2024-06-17 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.9523809523809526
# 2024-06-18 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.882352941176471
# 2024-06-19 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.813953488372093
# 2024-06-20 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.747126436781609
# 2024-06-21 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.681818181818182
# 2024-06-24 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.617977528089888
# 2024-06-25 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.555555555555555
# 2024-06-26 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.4945054945054945
# 2024-06-27 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.434782608695652
# 2024-06-28 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.376344086021505
# 2024-07-01 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.319148936170213
# 2024-07-02 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.2631578947368425
# 2024-07-03 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.208333333333333
# 2024-07-04 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.154639175257732
# 2024-07-05 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.1020408163265305
# 2024-07-08 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.05050505050505
# 2024-07-09 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 5.0
# 2024-07-10 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.9504950495049505
# 2024-07-11 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.901960784313726
# 2024-07-12 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.854368932038835
# 2024-07-15 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.8076923076923075
# 2024-07-16 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.761904761904762
# 2024-07-17 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.716981132075472
# 2024-07-18 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.672897196261682
# 2024-07-19 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.62962962962963
# 2024-07-22 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.587155963302752
# 2024-07-23 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.545454545454546
# 2024-07-24 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.504504504504505
# 2024-07-25 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.464285714285714
# 2024-07-26 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.424778761061947
# 2024-07-29 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.3923308593374628, rate: 0.37246300000002464, has position day: 5, has position rate: 4.385964912280702
# 2024-07-30 sale:  [] buy:  [] val:  100372.46300000002
# max_val: 100767.80619999999, max_drawdone: -0.4420133937578612, rate: 0.32239900000001853, has position day: 6, has position rate: 5.217391304347826
# 2024-07-31 sale:  [] buy:  [['SH.512880']] val:  100322.39900000002
# max_val: 100767.80619999999, max_drawdone: -0.7377427653078854, rate: 0.024399000000016713, has position day: 7, has position rate: 6.0344827586206895
# 2024-08-01 sale:  [] buy:  [] val:  100024.39900000002
# max_val: 100767.80619999999, max_drawdone: -1.6840767542679487, rate: -0.9292009999999777, has position day: 8, has position rate: 6.837606837606837
# 2024-08-02 sale:  [] buy:  [] val:  99070.79900000001
# max_val: 100767.80619999999, max_drawdone: -1.8615143771979774, rate: -1.1080010000000016, has position day: 9, has position rate: 7.627118644067797
# 2024-08-05 sale:  [] buy:  [] val:  98891.99900000001
# 98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.563025210084033
# 2024-08-06 sale:  [['SH.512880', -3.214285714285708]] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.5
# 2024-08-07 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.43801652892562
# 2024-08-08 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.377049180327869
# 2024-08-09 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.317073170731708
# 2024-08-12 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.258064516129032
# 2024-08-13 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.2
# 2024-08-14 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.142857142857143
# 2024-08-15 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.086614173228346
# 2024-08-16 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 7.03125
# 2024-08-19 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.976744186046512
# 2024-08-20 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.923076923076923
# 2024-08-21 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.870229007633588
# 2024-08-22 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.818181818181818
# 2024-08-23 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.7669172932330826
# 2024-08-26 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.7164179104477615
# 2024-08-27 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.666666666666667
# 2024-08-28 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.617647058823529
# 2024-08-29 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.569343065693431
# 2024-08-30 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.521739130434782
# 2024-09-02 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.474820143884892
# 2024-09-03 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.428571428571429
# 2024-09-04 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.382978723404255
# 2024-09-05 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.338028169014085
# 2024-09-06 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.293706293706293
# 2024-09-09 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.25
# 2024-09-10 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.206896551724138
# 2024-09-11 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.164383561643835
# 2024-09-12 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.122448979591836
# 2024-09-13 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.081081081081081
# 2024-09-18 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.040268456375839
# 2024-09-19 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 6.0
# 2024-09-20 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.0870375959420073, rate: -1.3352557999999846, has position day: 9, has position rate: 5.960264900662252
# 2024-09-23 sale:  [] buy:  [] val:  98664.74420000002
# max_val: 100767.80619999999, max_drawdone: -2.135939424669104, rate: -1.3845330999999703, has position day: 10, has position rate: 6.578947368421052
# 2024-09-24 sale:  [] buy:  [['SH.512880']] val:  98615.46690000003
# max_val: 100767.80619999999, max_drawdone: -2.135939424669104, rate: -0.2668720999999721, has position day: 11, has position rate: 7.189542483660131
# 2024-09-25 sale:  [] buy:  [['SH.510300'], ['SH.512100']] val:  99733.12790000002
# max_val: 103795.42790000002, max_drawdone: -2.135939424669104, rate: 3.7954279000000213, has position day: 12, has position rate: 7.792207792207792
# 2024-09-26 sale:  [] buy:  [] val:  103795.42790000002
# max_val: 108761.42790000002, max_drawdone: -2.135939424669104, rate: 8.76142790000003, has position day: 13, has position rate: 8.387096774193548
# 2024-09-27 sale:  [] buy:  [] val:  108761.42790000002
# max_val: 117549.52790000002, max_drawdone: -2.135939424669104, rate: 17.549527900000015, has position day: 14, has position rate: 8.974358974358974
# 2024-09-30 sale:  [] buy:  [] val:  117549.52790000002
# max_val: 125056.62790000002, max_drawdone: -2.135939424669104, rate: 25.056627900000024, has position day: 15, has position rate: 9.554140127388536
# 2024-10-08 sale:  [] buy:  [] val:  125056.62790000002
# 53268.505900000026
# err: not find record postion for code SH.512100
# max_val: 125056.62790000002, max_drawdone: -3.343862752595456, rate: 20.874905900000016, has position day: 16, has position rate: 10.126582278481013
# 2024-10-09 sale:  [['SH.510300', 16.36468219729653], ['SH.512100', 22.286313581541677]] buy:  [] val:  120874.90590000001
# 117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 10.062893081761006
# 2024-10-10 sale:  [['SH.512880', 29.663962920046345]] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 10.0
# 2024-10-11 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.937888198757763
# 2024-10-14 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.876543209876543
# 2024-10-15 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.815950920245399
# 2024-10-16 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.75609756097561
# 2024-10-17 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.696969696969697
# 2024-10-18 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.63855421686747
# 2024-10-21 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.580838323353293
# 2024-10-22 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.523809523809524
# 2024-10-23 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.467455621301776
# 2024-10-24 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.411764705882353
# 2024-10-25 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.35672514619883
# 2024-10-28 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.30232558139535
# 2024-10-29 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.248554913294798
# 2024-10-30 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.195402298850574
# 2024-10-31 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.142857142857142
# 2024-11-01 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.362811018991167, rate: 17.099511000000035, has position day: 16, has position rate: 9.090909090909092
# 2024-11-04 sale:  [] buy:  [] val:  117099.51100000003
# max_val: 125056.62790000002, max_drawdone: -6.409534332246295, rate: 17.041080400000027, has position day: 17, has position rate: 9.6045197740113
# 2024-11-05 sale:  [] buy:  [['SH.512880']] val:  117041.08040000004
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 16.919421800000038, has position day: 18, has position rate: 10.112359550561798
# 2024-11-06 sale:  [] buy:  [['SH.512100']] val:  116919.42180000004
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 22.47702180000003, has position day: 19, has position rate: 10.614525139664805
# 2024-11-07 sale:  [] buy:  [] val:  122477.02180000003
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.185521800000032, has position day: 20, has position rate: 11.11111111111111
# 2024-11-08 sale:  [] buy:  [] val:  120185.52180000003
# 90577.70580000004
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.97010580000004, has position day: 21, has position rate: 11.602209944751381
# 2024-11-11 sale:  [['SH.512880', 4.595879556259902]] buy:  [] val:  120970.10580000003
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.548305800000037, has position day: 22, has position rate: 12.087912087912088
# 2024-11-12 sale:  [] buy:  [] val:  120548.30580000003
# 120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 12.021857923497267
# 2024-11-13 sale:  [['SH.512100', 2.9423303256179025]] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.956521739130435
# 2024-11-14 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.891891891891891
# 2024-11-15 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.827956989247312
# 2024-11-18 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.764705882352942
# 2024-11-19 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.702127659574469
# 2024-11-20 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.640211640211641
# 2024-11-21 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.578947368421053
# 2024-11-22 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.518324607329843
# 2024-11-25 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.458333333333334
# 2024-11-26 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.398963730569948
# 2024-11-27 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.34020618556701
# 2024-11-28 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.282051282051283
# 2024-11-29 sale:  [] buy:  [] val:  120461.39220000005
# max_val: 125056.62790000002, max_drawdone: -6.506817140877018, rate: 20.46139220000005, has position day: 22, has position rate: 11.224489795918368
# 2024-12-02 sale:  [] buy:  [] val:  120461.39220000005
