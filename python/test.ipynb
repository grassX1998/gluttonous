# %%
from futuapi.futu_api import FutuApi

def run_futu_api():
    # 使用示例
    loader = FutuApi()
    loader.load_min_kline('SH.513100', '202407')  # A股红利ETF的代码
    loader.close()
    
run_futu_api()
# Out:
# 2024-08-23 14:59:14,119 | 265860 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1, host=127.0.0.1, port=11111, user_id=13389358
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6     loader.load_min_kline('SH.513100', '202407')  # A股红利ETF的代码
#       7     loader.close()
# ----> 9 run_futu_api()
#
# Cell In[1], line 5, in run_futu_api()
#       3 def run_futu_api():
#       4     # 使用示例
# ----> 5     loader = FutuApi()
#       6     loader.load_min_kline('SH.513100', '202407')  # A股红利ETF的代码
#       7     loader.close()
#
# File ~/workspace/projects/gluttonous/python/futuapi/futu_api.py:18, in FutuApi.__init__(self, host, port, ktype)
#      16 self.cfg_dir = "/mnt/nas/futu/A-shares/cfg"
#      17 os.makedirs(self.cfg_dir, exist_ok=True)  # 确保目录存在
# ---> 18 self.save_trading_days_to_toml()
#
# ...

# %%
import polars as pl

pl.read_parquet('/data/futu/A-shares/SH.512400/2022/2022-01-04.parquet')
# Out:
# shape: (241, 13)
# ┌───────────┬────────────┬────────────┬───────┬───┬─────────┬────────────┬────────────┬────────────┐
# │ code      ┆ name       ┆ time_key   ┆ open  ┆ … ┆ volume  ┆ turnover   ┆ change_rat ┆ last_close │
# │ ---       ┆ ---        ┆ ---        ┆ ---   ┆   ┆ ---     ┆ ---        ┆ e          ┆ ---        │
# │ str       ┆ str        ┆ str        ┆ f64   ┆   ┆ i64     ┆ f64        ┆ ---        ┆ f64        │
# │           ┆            ┆            ┆       ┆   ┆         ┆            ┆ f64        ┆            │
# ╞═══════════╪════════════╪════════════╪═══════╪═══╪═════════╪════════════╪════════════╪════════════╡
# │ SH.512400 ┆ China      ┆ 2022-01-04 ┆ 1.346 ┆ … ┆ 945200  ┆ 1.281691e6 ┆ 0.522778   ┆ 1.339      │
# │           ┆ Southern   ┆ 09:30:00   ┆       ┆   ┆         ┆            ┆            ┆            │
# │           ┆ CSI SWS    ┆            ┆       ┆   ┆         ┆            ┆            ┆            │
# ...
